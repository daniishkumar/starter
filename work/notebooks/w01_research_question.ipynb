# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# Lane: Predict Click-Through Rate (CTR)
#
# I chose the CTR prediction lane because improving click-through rate is an important SEO decision. Pages with low CTR may have good search rankings but fail to attract clicks due to weak titles or meta descriptions. Predicting CTR can help identify pages that need optimization.
#
# The goal is not simply to build a machine learning model, but to support better SEO decisions using historical Google Search Console data.

# %% [markdown]
# ## 2. The question: decision, action, cost of a wrong call
#
# #Research Question
#
# Can we predict the expected Click-Through Rate (CTR) of a webpage using search performance metrics such as impressions, average position, clicks, and other available features?
#
# #Decision
#
# Which pages should be prioritized for SEO improvements?
#
# #Action
#
# An SEO specialist can:
#
# Rewrite titles and meta descriptions.
# Improve page content.
# Optimize pages with high impressions but low predicted CTR.
# Cost of a Wrong Recommendation
#
# #If the model incorrectly identifies pages:
#
# Time may be wasted optimizing pages that do not need improvement.
# High-potential pages may be ignored.
# Website traffic growth could slow.
#
# #Why ML Can Help
#
# CTR depends on multiple factors that interact together. Machine learning can discover relationships between these variables and estimate expected CTR more effectively than simple manual rules.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
import pandas as pd

df = pd.read_csv("../data/search_console_clean.csv")

print("Rows:", len(df))
print("Columns:", len(df.columns))
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipykernel_1498/833192285.py in <cell line: 0>()
#       1 import pandas as pd
#       2
# ----> 3 df = pd.read_csv("../data/search_console_clean.csv")
#       4
#       5 print("Rows:", len(df))
#
# ...

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %%
import os

for root, dirs, files in os.walk("."):
    for file in files:
        if file.endswith(".csv"):
            print(os.path.join(root, file))
# Out:
# ./sample_data/mnist_train_small.csv
# ./sample_data/california_housing_train.csv
# ./sample_data/california_housing_test.csv
# ./sample_data/mnist_test.csv

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
